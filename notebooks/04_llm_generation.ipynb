# %%
import sys
sys.path.append('../src')
import pandas as pd
from llm_generator import generate_synthetic_dataset
# Out:
# C:\Users\Sahire\synthetic-data-benchmark\notebooks\../src\llm_generator.py:6: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
train_adult = pd.read_csv('../data/raw/adult_train.csv')

schema_desc = (
    "age (int, 17-90), workclass (categorical), education (categorical), "
    "marital-status (categorical), occupation (categorical), relationship (categorical), "
    "race (categorical), sex (categorical), hours-per-week (int, 1-99), "
    "native-country (categorical), income (categorical: <=50K or >50K)"
)

# Maliyet nedeniyle 500 satırla sınırlıyoruz — bunu raporda açıkça belirt (limitation)
llm_synthetic_adult, meta = generate_synthetic_dataset(
    train_adult, schema_desc, target_n=500, batch_size=20
)

llm_synthetic_adult.to_csv('../data/synthetic/adult_llm.csv', index=False)
print(meta)
# Out:
# Batch 1/25 tamamlandı, toplam satır: 20
# Batch 2/25 tamamlandı, toplam satır: 40
# Batch 3/25 tamamlandı, toplam satır: 60
# Batch 4/25 tamamlandı, toplam satır: 80
# Batch 5/25 tamamlandı, toplam satır: 100
# Batch 6/25 tamamlandı, toplam satır: 120
# Batch 7/25 tamamlandı, toplam satır: 140
# Batch 8/25 tamamlandı, toplam satır: 160
# Batch 9/25 tamamlandı, toplam satır: 180
# Batch 10/25 tamamlandı, toplam satır: 200
# Batch 11/25 tamamlandı, toplam satır: 220
# Batch 12/25 tamamlandı, toplam satır: 240
# Batch 13/25 tamamlandı, toplam satır: 260
# Batch 14/25 tamamlandı, toplam satır: 280
# Batch 15/25 tamamlandı, toplam satır: 300
# Batch 16/25 tamamlandı, toplam satır: 320
# Batch 17/25 tamamlandı, toplam satır: 340
# Batch 18/25 tamamlandı, toplam satır: 360
# Batch 19/25 tamamlandı, toplam satır: 380
# Batch 20/25 tamamlandı, toplam satır: 400
# Batch 21/25 tamamlandı, toplam satır: 420
# Batch 22/25 tamamlandı, toplam satır: 440
# Batch 23/25 tamamlandı, toplam satır: 460
# ...
